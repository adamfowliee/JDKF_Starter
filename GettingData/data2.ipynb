# %%
from fredapi import Fred
import pandas as pd

fred = Fred(api_key=API_KEY)

series_codes = {
    "real_gdp": "GDPC1",
    "industrial_production": "INDPRO",
    "unemployment_rate": "UNRATE",
    "nonfarm_payrolls": "PAYEMS",
    "cpi": "CPIAUCSL",
    "core_cpi": "CPILFESL",
    "ppi": "PPIACO",
    "fed_funds_rate": "FEDFUNDS",
    "baa_yield": "BAA",
    "ten_year_yield": "GS10",
    "yield_curve": "T10Y2Y",
    "sp500": "SP500",
    "vix": "VIXCLS",
    "house_price_index": "CSUSHPISA",
    "oil_price": "DCOILWTICO",
}

df1 = pd.DataFrame({
    name: fred.get_series(code)
    for name, code in series_codes.items()
})

df1 = df.loc["1970-01-01":"2025-12-31"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from fredapi import Fred
#       2 import pandas as pd
# ----> 4 fred = Fred(api_key=API_KEY)
#       6 series_codes = {
#       7     "real_gdp": "GDPC1",
#       8     "industrial_production": "INDPRO",
#    (...)
#      21     "oil_price": "DCOILWTICO",
#      22 }
#      24 df1 = pd.DataFrame({
#      25     name: fred.get_series(code)
#      26     for name, code in series_codes.items()
#      27 })
#
# NameError: name 'API_KEY' is not defined
