# %% [markdown]
# # HMM Regime Detection on the Latent Manifold — Corrected
#
# Fixes applied, tagged `[Fn]` inline:

# %%
from hmmlearn import hmm
import numpy as np, pandas as pd
import matplotlib.dates as mdates
from scipy.signal import find_peaks
from scipy.sparse import csr_matrix
from sklearn.neighbors import kneighbors_graph
from scipy.sparse.csgraph import shortest_path
from scipy.optimize import linear_sum_assignment
import matplotlib; import matplotlib.pyplot as plt
from scipy.spatial.distance import squareform, pdist, cdist
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, cohen_kappa_score
import warnings; warnings.filterwarnings("ignore")

N_DIFFUSION_COORDS = 3       # [F2]
RANDOM_STARTS = 100          # [F3]
EPS_DIFFUSION = 3
K_GRAPH = 15
BETA = 1.5

# %%
def diffusion_map(data, eps, alpha=1, k=4):
    Dsq=squareform(pdist(data)**2); Wm=np.exp(-Dsq/eps); q=Wm.sum(1)
    Wa=Wm/np.outer(q**alpha,q**alpha); da=Wa.sum(1); Dis=1.0/np.sqrt(da)
    S=Dis[:,None]*Wa*Dis[None,:]; w,v=np.linalg.eigh(S)
    idx=np.argsort(w)[::-1]; w,v=w[idx],v[:,idx]; phi=Dis[:,None]*v
    return {"evals":w,"Psi":phi[:,1:k+1]*w[1:k+1],
            "store":dict(data=data,eps=eps,alpha=alpha,q=q,w=w,phi=phi)}

def nystrom_extend(y_new, store, k):
    """[F1] Extend unseen points into an embedding fitted on TRAIN only."""
    eps,alpha=store["eps"],store["alpha"]
    lam=store["w"][1:k+1]; phi=store["phi"][:,1:k+1]
    y_new=np.atleast_2d(y_new)
    wn=np.exp(-cdist(y_new,store["data"])**2/eps); qn=wn.sum(1,keepdims=True)
    wa=wn/((qn**alpha)*(store["q"][None,:]**alpha)); pn=wa/wa.sum(1,keepdims=True)
    return lam*((pn@phi)/lam)

def graph_degree_density(Psi,h):
    Dsq=squareform(pdist(Psi)**2); rho=np.exp(-Dsq/h).sum(1); scale=rho.mean(); rho/=scale
    rho=np.maximum(rho,1e-6); return rho,-np.log(rho),scale
def density_and_bandwidth(Psi,mult=0.1):
    N=Psi.shape[0]; med=np.median(squareform(pdist(Psi)**2)[np.triu_indices(N,1)])
    return mult*med, med, graph_degree_density(Psi,mult*med)
def reconstruct_path(pred,s,e):
    p=[e]; c=e
    while c!=s:
        c=pred[s,c]
        if c==-9999: return None
        p.append(c)
    return p[::-1]
def graph_path(A,beta,V,s,e):
    r,c=A.nonzero(); base=np.asarray(A[r,c]).ravel()
    Cst=csr_matrix((base*np.exp(beta*(V[r]+V[c])/2),(r,c)),shape=A.shape)
    _,pred=shortest_path(Cst,directed=False,return_predecessors=True)
    return reconstruct_path(pred,s,e)

def best_hmm_model(X,K,n_starts=RANDOM_STARTS):
    X=np.asarray(X,float); best=-np.inf; bm=None; nf=0
    for seed in range(n_starts):
        m=hmm.GaussianHMM(n_components=K,covariance_type="full",n_iter=200,
                          random_state=seed,tol=1e-4)
        try: m.fit(X); s=m.score(X)
        except Exception: nf+=1; continue
        if np.isfinite(s) and s>best: best=s; bm=m
    if bm is None: raise RuntimeError(f"all inits failed for K={K}")
    return bm,best,nf
def hmm_parameter_count(K,d): return (K-1)+K*(K-1)+K*d+K*d*(d+1)//2

# %% [markdown]
# ## Data. `transformed_observed_df` supplies interpretable macro units.

# %%
df = pd.read_parquet("./datasets/joint_df_quantile.parquet")
dates = df.index; variables = df.columns[:-1]
Z = df.to_numpy()[:, :-1]; N = Z.shape[0]
obs_df = pd.read_parquet("./datasets/transformed_observed_df.parquet").loc[dates]

diff = diffusion_map(Z, EPS_DIFFUSION, k=N_DIFFUSION_COORDS)
Psi = diff["Psi"]
h_dens, med_Dsq, (rho, V, scale) = density_and_bandwidth(Psi)
A_dist = kneighbors_graph(Psi, n_neighbors=K_GRAPH, mode="distance", include_self=False)
A_dist_sym = A_dist.maximum(A_dist.T)

endpoint_pairs={"2006 benign -> 2008 GFC":("2006-03-01","2008-10-01"),
 "2019 benign -> 2020 COVID":("2019-07-01","2020-04-01"),
 "2019 benign -> 2021 Fiscal Tightening":("2019-04-01","2022-04-01"),
 "1977 benign -> 1982 Recession Trough":("1977-01-01","1982-07-01")}
pairs={n:(dates.get_loc(a),dates.get_loc(b)) for n,(a,b) in endpoint_pairs.items()}
print("N =",N," Psi",Psi.shape)
print("eigenvalues:",np.round(diff["evals"][1:6],4))
# Out:
# N = 743  Psi (743, 3)
# eigenvalues: [0.4336 0.3693 0.2331 0.2209 0.2092]

# %% [markdown]
# ## Task IV.1 — model selection with an honest out-of-sample split
#
# **[F1]** The embedding is refitted on the training months alone; test months enter by Nyström
# extension. Fitting the diffusion map on all 743 months and then slicing would leak the test
# period into the eigenvectors, the α-normalisation and the density.

# %%
split_idx = dates.get_loc("2007-01-01")

# [F1] honest: DM on train only, Nystrom-extend the test months
diff_train = diffusion_map(Z[:split_idx], EPS_DIFFUSION, k=N_DIFFUSION_COORDS)
Psi_train  = diff_train["Psi"]
Psi_test   = nystrom_extend(Z[split_idx:], diff_train["store"], k=N_DIFFUSION_COORDS)
print("train", Psi_train.shape, " test (Nystrom)", Psi_test.shape,
      "| split at", dates[split_idx].date())
# Out:
# train (511, 3)  test (Nystrom) (232, 3) | split at 2007-01-01

# %%
rows=[]; models={}
T,d = Psi.shape
for K in [2,3,4,5,6,7]:
    bm,bs,nf = best_hmm_model(Psi,K)
    p   = hmm_parameter_count(K,d)
    bic = p*np.log(T) - 2*bs
    m_tr,_,_ = best_hmm_model(Psi_train,K)
    oos = m_tr.score(Psi_test)/len(Psi_test)      # [F5] per-point
    rows.append({"n_components":K,"params":p,"obs_per_param":round(T/p,1),
                 "BIC":bic,"OOS_ll_per_point":oos})
    models[K]=bm
hmm_df=pd.DataFrame(rows)
print(hmm_df.round(4).to_string(index=False))
print("\nBIC argmin  -> K =", int(hmm_df.loc[hmm_df.BIC.idxmin(),"n_components"]))
print("OOS argmax  -> K =", int(hmm_df.loc[hmm_df.OOS_ll_per_point.idxmax(),"n_components"]))
# Out:
# Model is not converging.  Current: 2249.479796996187 is not greater than 2249.480171685708. Delta is -0.00037468952086783247
# Model is not converging.  Current: 2249.480455252415 is not greater than 2249.480482086702. Delta is -2.6834286927623907e-05
# Model is not converging.  Current: 2249.480371447571 is not greater than 2249.4805058486213. Delta is -0.00013440105021800264
# Model is not converging.  Current: 2249.4803461505708 is not greater than 2249.4805032564245. Delta is -0.00015710585375927621
# Model is not converging.  Current: 2252.1390146991334 is not greater than 2252.1390727550047. Delta is -5.8055871249962365e-05
# Model is not converging.  Current: 2252.138780491004 is not greater than 2252.139153363911. Delta is -0.00037287290706444765
# Model is not converging.  Current: 2252.1389887410464 is not greater than 2252.13900205322. Delta is -1.3312173450685805e-05
# Model is not converging.  Current: 2252.1390005664844 is not greater than 2252.1390670667665. Delta is -6.650028217336512e-05
# Model is not converging.  Current: 2249.4804370899265 is not greater than 2249.4805060689105. Delta is -6.897898401803104e-05
# Model is not converging.  Current: 2249.4804169048484 is not greater than 2249.480501563421. Delta is -8.465857263217913e-05
# Model is not converging.  Current: 2252.139034403849 is not greater than 2252.1390691997003. Delta is -3.4795851206581574e-05
# Model is not converging.  Current: 2252.139011991587 is not greater than 2252.139072990348. Delta is -6.099876100051915e-05
# Model is not converging.  Current: 2249.4803792850917 is not greater than 2249.4805060308818. Delta is -0.00012674579011218157
# Model is not converging.  Current: 2252.139002740424 is not greater than 2252.1390767472762. Delta is -7.400685217362479e-05
# Model is not converging.  Current: 2252.1400572942453 is not greater than 2252.14108705611. Delta is -0.0010297618646291085
# Model is not converging.  Current: 2252.1390325097996 is not greater than 2252.1390776300445. Delta is -4.5120244976715185e-05
# Model is not converging.  Current: 2249.4804147885975 is not greater than 2249.4805019964588. Delta is -8.720786127014435e-05
# Model is not converging.  Current: 2252.139042878541 is not greater than 2252.139062072059. Delta is -1.9193517800886184e-05
# Model is not converging.  Current: 2249.4767367088807 is not greater than 2249.4768130582947. Delta is -7.634941403011908e-05
# Model is not converging.  Current: 2249.4804131462556 is not greater than 2249.480502458312. Delta is -8.931205638873507e-05
# Model is not converging.  Current: 2249.4803729240707 is not greater than 2249.4805074213396. Delta is -0.00013449726884573465
# Model is not converging.  Current: 2249.48035934651 is not greater than 2249.4805049617908. Delta is -0.00014561528087142506
# Model is not converging.  Current: 2249.480436555665 is not greater than 2249.4804940905306. Delta is -5.753486539106234e-05
# Model is not converging.  Current: 2252.139542203463 is not greater than 2252.1402362506124. Delta is -0.0006940471494090161
# Model is not converging.  Current: 2249.480330686726 is not greater than 2249.4805003754095. Delta is -0.00016968868339972687
# Model is not converging.  Current: 2249.4804303121323 is not greater than 2249.4804969119696. Delta is -6.659983728241059e-05
# Model is not converging.  Current: 2249.4803960635168 is not greater than 2249.480505231842. Delta is -0.00010916832525253994
# Model is not converging.  Current: 2249.480391045615 is not greater than 2249.480505651406. Delta is -0.0001146057911682874
# Model is not converging.  Current: 1485.7884389889682 is not greater than 1485.7885480823572. Delta is -0.00010909338902820309
# Model is not converging.  Current: 1485.7883997088888 is not greater than 1485.788505580336. Delta is -0.00010587144720375363
# Model is not converging.  Current: 1485.7886039872071 is not greater than 1485.7890327619525. Delta is -0.00042877474538727256
# Model is not converging.  Current: 1485.788360054182 is not greater than 1485.7884241458921. Delta is -6.409171010091086e-05
# Model is not converging.  Current: 1485.7883706366672 is not greater than 1485.788419131639. Delta is -4.8494971906620776e-05
# Model is not converging.  Current: 1485.788311623732 is not greater than 1485.788321878676. Delta is -1.0254944072585204e-05
# Model is not converging.  Current: 1485.7883336168363 is not greater than 1485.7883775792882. Delta is -4.3962451854895335e-05
# Model is not converging.  Current: 2562.774855265589 is not greater than 2562.777225399272. Delta is -0.0023701336831436493
# Model is not converging.  Current: 2562.8073167109496 is not greater than 2562.8269799753652. Delta is -0.019663264415612502
# Model is not converging.  Current: 2333.908396906668 is not greater than 2333.9084813314307. Delta is -8.44247629174788e-05
# Model is not converging.  Current: 2562.7922356316667 is not greater than 2562.7987991378877. Delta is -0.006563506221027637
# Model is not converging.  Current: 2562.786517133353 is not greater than 2562.791930440844. Delta is -0.005413307491380692
# Model is not converging.  Current: 2562.7890720580544 is not greater than 2562.795849597533. Delta is -0.00677753947866222
# Model is not converging.  Current: 2333.908430231592 is not greater than 2333.9085394163453. Delta is -0.00010918475345533807
# Model is not converging.  Current: 2562.790659149026 is not greater than 2562.7953639257485. Delta is -0.004704776722519455
# Model is not converging.  Current: 2562.7746861383253 is not greater than 2562.777274204698. Delta is -0.002588066372936737
# Model is not converging.  Current: 2562.7930181533056 is not greater than 2562.7981746345467. Delta is -0.005156481241101574
# Model is not converging.  Current: 2326.7039558854635 is not greater than 2326.705530808664. Delta is -0.0015749232006783132
# Model is not converging.  Current: 2562.7882696813836 is not greater than 2562.789722457633. Delta is -0.0014527762496072683
# Model is not converging.  Current: 2324.4459578326378 is not greater than 2324.4464452732345. Delta is -0.00048744059677119367
# Model is not converging.  Current: 2562.786220359469 is not greater than 2562.7925020390626. Delta is -0.006281679593485023
# Model is not converging.  Current: 2562.7894202821544 is not greater than 2562.79326463237. Delta is -0.0038443502157861076
# Model is not converging.  Current: 2333.9083023709127 is not greater than 2333.9083430284304. Delta is -4.0657517729414394e-05
# Model is not converging.  Current: 2562.7909777294744 is not greater than 2562.7969734111334. Delta is -0.005995681658987451
# Model is not converging.  Current: 2562.807811457202 is not greater than 2562.8185437030456. Delta is -0.010732245843428245
# Model is not converging.  Current: 2311.6735959600014 is not greater than 2311.673628994113. Delta is -3.303411176602822e-05
# Model is not converging.  Current: 2562.806985946697 is not greater than 2562.8111909625027. Delta is -0.00420501580583732
# Model is not converging.  Current: 2562.7852740410935 is not greater than 2562.790597740904. Delta is -0.005323699810560356
# Model is not converging.  Current: 2527.0289641314857 is not greater than 2527.0384891280873. Delta is -0.009524996601612656
# Model is not converging.  Current: 2562.8037832402674 is not greater than 2562.807125432818. Delta is -0.0033421925504626415
# Model is not converging.  Current: 2562.78054523729 is not greater than 2562.7823623479976. Delta is -0.0018171107076341286
# Model is not converging.  Current: 2562.7854998074563 is not greater than 2562.7859075229862. Delta is -0.0004077155299455626
# Model is not converging.  Current: 2562.7802770043945 is not greater than 2562.784538956675. Delta is -0.0042619522805580345
# Model is not converging.  Current: 2326.7000746087137 is not greater than 2326.7004897637266. Delta is -0.0004151550128881354
# Model is not converging.  Current: 2562.7939804354755 is not greater than 2562.798876174275. Delta is -0.0048957387994050805
# Model is not converging.  Current: 2562.7967098653817 is not greater than 2562.798360876398. Delta is -0.001651011016292614
# Model is not converging.  Current: 2562.7834927273893 is not greater than 2562.7888549924587. Delta is -0.005362265069379646
# Model is not converging.  Current: 2562.787957208211 is not greater than 2562.789247928736. Delta is -0.0012907205250485276
# Model is not converging.  Current: 2562.775209047165 is not greater than 2562.7774309545152. Delta is -0.002221907350303809
# Model is not converging.  Current: 2527.0331581226533 is not greater than 2527.037942035931. Delta is -0.004783913277606189
# Model is not converging.  Current: 2562.781577762956 is not greater than 2562.7835580451797. Delta is -0.001980282223485119
# Model is not converging.  Current: 2562.779374473699 is not greater than 2562.783249377293. Delta is -0.003874903593896306
# Model is not converging.  Current: 2326.6996191967064 is not greater than 2326.7002456086993. Delta is -0.0006264119929255685
# Model is not converging.  Current: 2562.795442474717 is not greater than 2562.797249412208. Delta is -0.0018069374909828184
# Model is not converging.  Current: 2562.798768423341 is not greater than 2562.8062760663724. Delta is -0.007507643031658517
# Model is not converging.  Current: 2562.787483644095 is not greater than 2562.789902868241. Delta is -0.002419224145796761
# Model is not converging.  Current: 2562.788230414863 is not greater than 2562.794465255331. Delta is -0.006234840468096081
# Model is not converging.  Current: 2562.7803982495175 is not greater than 2562.783876929636. Delta is -0.003478680118405464
# Model is not converging.  Current: 2562.783435366593 is not greater than 2562.7866667494427. Delta is -0.003231382849662623
# Model is not converging.  Current: 2562.791885897222 is not greater than 2562.7960734851968. Delta is -0.004187587974683993
# Model is not converging.  Current: 2333.9072680693544 is not greater than 2333.907270681589. Delta is -2.6122347662749235e-06
# Model is not converging.  Current: 2562.794737069051 is not greater than 2562.800700794894. Delta is -0.00596372584323035
# Model is not converging.  Current: 2562.7936428323897 is not greater than 2562.7973427012826. Delta is -0.003699868892908853
# Model is not converging.  Current: 2562.7831608465776 is not greater than 2562.7879189019163. Delta is -0.004758055338697886
# Model is not converging.  Current: 2562.7910034450492 is not greater than 2562.8103828420976. Delta is -0.01937939704839664
# Model is not converging.  Current: 2562.8173000324864 is not greater than 2562.817304688317. Delta is -4.655830707633868e-06
# Model is not converging.  Current: 2562.78022844542 is not greater than 2562.783615839078. Delta is -0.0033873936577037966
# Model is not converging.  Current: 2333.9081315086246 is not greater than 2333.908157453758. Delta is -2.594513352960348e-05
# Model is not converging.  Current: 2562.78904917172 is not greater than 2562.7907183539623. Delta is -0.0016691822424945713
# Model is not converging.  Current: 2562.7835409806985 is not greater than 2562.788751083985. Delta is -0.005210103286572121
# Model is not converging.  Current: 2562.78497795532 is not greater than 2562.789900928488. Delta is -0.0049229731680497935
# Model is not converging.  Current: 2562.792083320034 is not greater than 2562.797420033474. Delta is -0.005336713439646701
# Model is not converging.  Current: 2562.774200375019 is not greater than 2562.7766684224393. Delta is -0.0024680474202796177
# Model is not converging.  Current: 2333.905519646914 is not greater than 2333.905591327174. Delta is -7.168026013459894e-05
# Model is not converging.  Current: 2326.701982350866 is not greater than 2326.702136957062. Delta is -0.00015460619624718674
# Model is not converging.  Current: 2562.790744359692 is not greater than 2562.7981436211016. Delta is -0.007399261409773317
# Model is not converging.  Current: 2562.793745462586 is not greater than 2562.7973516799834. Delta is -0.0036062173976461054
# Model is not converging.  Current: 2333.9015998714763 is not greater than 2333.901601199772. Delta is -1.32829563881387e-06
# Model is not converging.  Current: 2562.784538637334 is not greater than 2562.789411517317. Delta is -0.004872879982940503
# Model is not converging.  Current: 2562.784081805355 is not greater than 2562.789235489904. Delta is -0.005153684548986348
# Model is not converging.  Current: 2562.797323491378 is not greater than 2562.798759797986. Delta is -0.0014363066079567943
# Model is not converging.  Current: 2562.788961961812 is not greater than 2562.7961524925486. Delta is -0.00719053073635223
# Model is not converging.  Current: 2561.9449234186764 is not greater than 2561.945635029934. Delta is -0.0007116112574294675
# Model is not converging.  Current: 2562.783534930167 is not greater than 2562.788678804504. Delta is -0.00514387433668162
# Model is not converging.  Current: 2561.9650356832726 is not greater than 2561.965244611004. Delta is -0.00020892773136438336
# Model is not converging.  Current: 2562.7920930010746 is not greater than 2562.7966557625023. Delta is -0.004562761427678197
# Model is not converging.  Current: 2562.79567559746 is not greater than 2562.800002865054. Delta is -0.004327267593907891
# Model is not converging.  Current: 1660.750995399975 is not greater than 1660.7510344226164. Delta is -3.902264143107459e-05
# Model is not converging.  Current: 1602.7510032768039 is not greater than 1602.761892999531. Delta is -0.010889722727142725
# Model is not converging.  Current: 1622.8197837930516 is not greater than 1622.82022166895. Delta is -0.0004378758983420994
# Model is not converging.  Current: 1622.8197113259687 is not greater than 1622.820114548831. Delta is -0.0004032228623600531
# Model is not converging.  Current: 1599.1098845791869 is not greater than 1599.1100991547532. Delta is -0.00021457556636050867
# Model is not converging.  Current: 1632.7289067252066 is not greater than 1632.7292123103869. Delta is -0.00030558518028556136
# Model is not converging.  Current: 1632.7285932324517 is not greater than 1632.7296534089546. Delta is -0.0010601765029605303
# Model is not converging.  Current: 1632.7285711652994 is not greater than 1632.7296753633368. Delta is -0.0011041980374102423
# Model is not converging.  Current: 1622.8195723421375 is not greater than 1622.8202366371409. Delta is -0.0006642950033892703
# Model is not converging.  Current: 1632.7289918783492 is not greater than 1632.7290425491549. Delta is -5.06708056491334e-05
# Model is not converging.  Current: 1622.8196235404425 is not greater than 1622.82053546065. Delta is -0.0009119202074998611
# Model is not converging.  Current: 1660.7509225502672 is not greater than 1660.7513341205422. Delta is -0.00041157027499139076
# Model is not converging.  Current: 1602.8185775442662 is not greater than 1602.8265020372128. Delta is -0.007924492946585815
# Model is not converging.  Current: 1622.819046115848 is not greater than 1622.8204240427822. Delta is -0.001377926934083007
# Model is not converging.  Current: 1632.7286770829628 is not greater than 1632.7295600715036. Delta is -0.0008829885407521942
# Model is not converging.  Current: 1660.7534084830377 is not greater than 1660.7547020299767. Delta is -0.0012935469389958598
# Model is not converging.  Current: 1632.7275925977947 is not greater than 1632.7298628855137. Delta is -0.002270287719056796
# Model is not converging.  Current: 1632.727488100917 is not greater than 1632.7298160532062. Delta is -0.002327952289078894
# Model is not converging.  Current: 1622.8137821118282 is not greater than 1622.8139635394434. Delta is -0.00018142761518902262
# Model is not converging.  Current: 1605.0646759099848 is not greater than 1605.0651337824418. Delta is -0.0004578724569910264
# Model is not converging.  Current: 1602.788581358208 is not greater than 1602.791778246389. Delta is -0.0031968881810371386
# Model is not converging.  Current: 1632.7279773735413 is not greater than 1632.7299413802639. Delta is -0.0019640067225736857
# Model is not converging.  Current: 1602.77621684538 is not greater than 1602.7827139336432. Delta is -0.006497088263131445
# Model is not converging.  Current: 1601.2381317237578 is not greater than 1601.238530228842. Delta is -0.0003985050841492921
# Model is not converging.  Current: 1632.7284525625018 is not greater than 1632.7297761959833. Delta is -0.001323633481433717
# Model is not converging.  Current: 1632.7273839550285 is not greater than 1632.729759926011. Delta is -0.002375970982484432
# Model is not converging.  Current: 1632.7271750918007 is not greater than 1632.7296213375007. Delta is -0.002446245699957217
# Model is not converging.  Current: 1632.7282373474595 is not greater than 1632.72989355939. Delta is -0.0016562119303671352
# Model is not converging.  Current: 1632.7284655206895 is not greater than 1632.7297665255255. Delta is -0.001301004836022912
# Model is not converging.  Current: 1601.2383468268722 is not greater than 1601.23837120244. Delta is -2.4375567818424315e-05
# Model is not converging.  Current: 1599.4172723708643 is not greater than 1599.4172893382267. Delta is -1.696736239864549e-05
# Model is not converging.  Current: 1661.2382485672633 is not greater than 1661.2514722628443. Delta is -0.013223695581018546
# Model is not converging.  Current: 1632.7268875629309 is not greater than 1632.7293802286365. Delta is -0.002492665705631225
# Model is not converging.  Current: 1621.9414926344245 is not greater than 1621.942843349963. Delta is -0.001350715538364966
# Model is not converging.  Current: 1661.2600510579434 is not greater than 1661.2834162507052. Delta is -0.023365192761730214
# Model is not converging.  Current: 1622.8193974150827 is not greater than 1622.8203294493333. Delta is -0.000932034250581637
# Model is not converging.  Current: 1632.7285317582073 is not greater than 1632.7297120065602. Delta is -0.0011802483529663732
# Model is not converging.  Current: 1632.7288382138358 is not greater than 1632.7293316952027. Delta is -0.0004934813669024152
# Model is not converging.  Current: 1632.7272078007568 is not greater than 1632.7296452041776. Delta is -0.0024374034207994555
# Model is not converging.  Current: 1622.8197755085903 is not greater than 1622.8200411077316. Delta is -0.00026559914135759755
# Model is not converging.  Current: 1622.8190045228741 is not greater than 1622.8204241836622. Delta is -0.00141966078808764
# Model is not converging.  Current: 1622.818784843891 is not greater than 1622.8203656987903. Delta is -0.0015808548992026772
# Model is not converging.  Current: 1632.7267960605534 is not greater than 1632.7292926120972. Delta is -0.0024965515437997965
# Model is not converging.  Current: 1622.8194554128643 is not greater than 1622.8203080242533. Delta is -0.0008526113890638953
# Model is not converging.  Current: 1622.818215926246 is not greater than 1622.8201322839645. Delta is -0.001916357718528161
# Model is not converging.  Current: 1632.7282362176047 is not greater than 1632.7298939753757. Delta is -0.001657757770999524
# Model is not converging.  Current: 1632.7285300119038 is not greater than 1632.7297135561078. Delta is -0.0011835442039682675
# Model is not converging.  Current: 2619.2570970369984 is not greater than 2619.2580941011465. Delta is -0.0009970641481231723
# Model is not converging.  Current: 2627.397294721503 is not greater than 2627.3998124145774. Delta is -0.0025176930744237325
# Model is not converging.  Current: 2619.659668388566 is not greater than 2619.6598066371807. Delta is -0.0001382486148031603
# Model is not converging.  Current: 2627.388124538616 is not greater than 2627.3899315628. Delta is -0.0018070241840177914
# Model is not converging.  Current: 2627.395557925795 is not greater than 2627.3991669555344. Delta is -0.0036090297394366644
# Model is not converging.  Current: 2619.661302728902 is not greater than 2619.6614751083985. Delta is -0.00017237949668924557
# Model is not converging.  Current: 2619.6615263619833 is not greater than 2619.6615289103306. Delta is -2.548347310948884e-06
# Model is not converging.  Current: 2613.937488691807 is not greater than 2613.9428320687107. Delta is -0.0053433769035109435
# Model is not converging.  Current: 2619.661410974225 is not greater than 2619.6615624254196. Delta is -0.00015145119459702983
# Model is not converging.  Current: 2619.062741345457 is not greater than 2619.062824256725. Delta is -8.291126778203761e-05
# Model is not converging.  Current: 2615.3051592512 is not greater than 2615.3057144906434. Delta is -0.0005552394432015717
# Model is not converging.  Current: 2626.0622621337816 is not greater than 2626.062717114702. Delta is -0.0004549809204945632
# Model is not converging.  Current: 2654.8044117982436 is not greater than 2654.8110332358187. Delta is -0.006621437575176969
# Model is not converging.  Current: 2627.3880786394366 is not greater than 2627.39034787125. Delta is -0.0022692318134431844
# Model is not converging.  Current: 2626.1721052205203 is not greater than 2626.1732173581836. Delta is -0.001112137663312751
# Model is not converging.  Current: 2619.6532963907175 is not greater than 2619.6532990694154. Delta is -2.6786979105963837e-06
# Model is not converging.  Current: 2627.4133990071487 is not greater than 2627.4176118043306. Delta is -0.004212797181935457
# Model is not converging.  Current: 2619.6664647206744 is not greater than 2619.6671633726687. Delta is -0.000698651994298416
# Model is not converging.  Current: 2619.6614071446843 is not greater than 2619.661470622888. Delta is -6.347820362861967e-05
# Model is not converging.  Current: 2654.7750061243773 is not greater than 2654.775061185875. Delta is -5.506149773282232e-05
# Model is not converging.  Current: 2619.661169169062 is not greater than 2619.6613321405644. Delta is -0.00016297150250466075
# Model is not converging.  Current: 2619.6614150628448 is not greater than 2619.6615829623693. Delta is -0.00016789952451290446
# Model is not converging.  Current: 2608.996354336035 is not greater than 2608.9998081931476. Delta is -0.0034538571126176976
# Model is not converging.  Current: 2618.5563681495746 is not greater than 2618.570246555329. Delta is -0.013878405754439882
# Model is not converging.  Current: 2618.3268732258966 is not greater than 2618.3274448295715. Delta is -0.0005716036748708575
# Model is not converging.  Current: 2619.655193715575 is not greater than 2619.655274061226. Delta is -8.034565098569146e-05
# Model is not converging.  Current: 2619.6614546255128 is not greater than 2619.6616504324556. Delta is -0.00019580694288379163
# Model is not converging.  Current: 2608.841511981226 is not greater than 2608.843736199155. Delta is -0.0022242179288696207
# Model is not converging.  Current: 2654.796274050265 is not greater than 2654.801897651324. Delta is -0.005623601059141947
# Model is not converging.  Current: 2619.6618130251104 is not greater than 2619.661961214634. Delta is -0.00014818952377027017
# Model is not converging.  Current: 2621.9285742357392 is not greater than 2621.9290888389014. Delta is -0.0005146031621734437
# Model is not converging.  Current: 2619.6804906190055 is not greater than 2619.6854058739827. Delta is -0.004915254977277073
# Model is not converging.  Current: 2610.8747095188614 is not greater than 2610.8760010290894. Delta is -0.0012915102279293933
# Model is not converging.  Current: 2627.406072276303 is not greater than 2627.409958970779. Delta is -0.003886694476022967
# Model is not converging.  Current: 2619.661607295807 is not greater than 2619.6616472082133. Delta is -3.991240646428196e-05
# Model is not converging.  Current: 2619.665452734464 is not greater than 2619.6701211345503. Delta is -0.004668400086302427
# Model is not converging.  Current: 2627.416088882745 is not greater than 2627.4168052623972. Delta is -0.0007163796522036137
# Model is not converging.  Current: 2613.5172699704694 is not greater than 2613.5200427294844. Delta is -0.002772759014987969
# Model is not converging.  Current: 2627.4122689601086 is not greater than 2627.412733723173. Delta is -0.00046476306442855275
# Model is not converging.  Current: 2619.6615508168225 is not greater than 2619.661727386889. Delta is -0.00017657006674198783
# Model is not converging.  Current: 2627.4077896177846 is not greater than 2627.413047682916. Delta is -0.005258065131329204
# Model is not converging.  Current: 2619.659202941828 is not greater than 2619.660106113623. Delta is -0.000903171795016533
# Model is not converging.  Current: 2627.3951972527966 is not greater than 2627.396989839736. Delta is -0.0017925869392456661
# Model is not converging.  Current: 2627.413830890871 is not greater than 2627.4172210027077. Delta is -0.003390111836779397
# Model is not converging.  Current: 2627.4150808742856 is not greater than 2627.4185218973585. Delta is -0.0034410230728099123
# Model is not converging.  Current: 2619.686534268448 is not greater than 2619.692367973209. Delta is -0.00583370476078926
# Model is not converging.  Current: 2619.6702398754232 is not greater than 2619.671413410238. Delta is -0.0011735348148249614
# Model is not converging.  Current: 2619.2463318832733 is not greater than 2619.2465539825903. Delta is -0.0002220993169430585
# Model is not converging.  Current: 1763.53514396404 is not greater than 1763.5401714745335. Delta is -0.005027510493619047
# Model is not converging.  Current: 1690.625741835025 is not greater than 1690.6257423899845. Delta is -5.549593424802879e-07
# Model is not converging.  Current: 1628.0086549474179 is not greater than 1628.0115572455566. Delta is -0.002902298138678816
# Model is not converging.  Current: 1762.0876450057401 is not greater than 1762.0878769065077. Delta is -0.00023190076763057732
# Model is not converging.  Current: 1686.5359295578019 is not greater than 1686.5380895573091. Delta is -0.0021599995072847378
# Model is not converging.  Current: 1721.1353278238264 is not greater than 1721.1354565666786. Delta is -0.00012874285221187165
# Model is not converging.  Current: 1709.5095792513268 is not greater than 1709.5145785770633. Delta is -0.004999325736434912
# Model is not converging.  Current: 1720.666622218251 is not greater than 1720.6795107621217. Delta is -0.01288854387075844
# Model is not converging.  Current: 1727.4474220912991 is not greater than 1727.4476454351357. Delta is -0.00022334383652378165
# Model is not converging.  Current: 1691.270580711556 is not greater than 1691.2713183007215. Delta is -0.0007375891655101441
# Model is not converging.  Current: 1764.2929337813432 is not greater than 1764.2977248707768. Delta is -0.0047910894336382626
# Model is not converging.  Current: 1727.9163180782514 is not greater than 1727.9174003225708. Delta is -0.0010822443193774234
# Model is not converging.  Current: 1706.169547458973 is not greater than 1706.2035220939586. Delta is -0.03397463498549769
# Model is not converging.  Current: 1669.8919877769463 is not greater than 1669.8923461373238. Delta is -0.00035836037750414107
# Model is not converging.  Current: 1764.2847927234577 is not greater than 1764.2858142127138. Delta is -0.0010214892561180022
# Model is not converging.  Current: 1686.5362903074686 is not greater than 1686.5383517556506. Delta is -0.0020614481820757646
# Model is not converging.  Current: 1633.9025016681805 is not greater than 1633.9039192411603. Delta is -0.0014175729797898384
# Model is not converging.  Current: 1688.0276482625638 is not greater than 1688.0311069900174. Delta is -0.00345872745356246
# Model is not converging.  Current: 1749.3374516001006 is not greater than 1749.3399298253107. Delta is -0.002478225210097662
# Model is not converging.  Current: 1633.7160848882068 is not greater than 1633.7176406271635. Delta is -0.0015557389567675273
# Model is not converging.  Current: 1727.9066511634996 is not greater than 1727.9070265384398. Delta is -0.00037537494017669815
# Model is not converging.  Current: 1663.3606311831659 is not greater than 1663.360791031183. Delta is -0.00015984801711965702
# Model is not converging.  Current: 1727.433286171588 is not greater than 1727.4333052158856. Delta is -1.9044297687287326e-05
# Model is not converging.  Current: 1767.3990069781369 is not greater than 1767.4014538833949. Delta is -0.0024469052580116113
# Model is not converging.  Current: 1688.0285336883805 is not greater than 1688.0321717491329. Delta is -0.003638060752336969
# Model is not converging.  Current: 1758.597623355843 is not greater than 1758.5982540547366. Delta is -0.0006306988934738911
# Model is not converging.  Current: 1749.4450937907104 is not greater than 1749.4794026497773. Delta is -0.034308859066868536
# Model is not converging.  Current: 1727.9085314231575 is not greater than 1727.9094001584383. Delta is -0.0008687352808465221
# Model is not converging.  Current: 1766.0956297449068 is not greater than 1766.1030177610046. Delta is -0.007388016097820582
# Model is not converging.  Current: 1603.6668921230475 is not greater than 1603.6705385585458. Delta is -0.0036464354982399527
# Model is not converging.  Current: 1758.6018963829172 is not greater than 1758.6054497219159. Delta is -0.0035533389986994734
# Model is not converging.  Current: 1686.5367669576508 is not greater than 1686.5383935519137. Delta is -0.0016265942629161145
# Model is not converging.  Current: 1686.5399507830782 is not greater than 1686.5441823236495. Delta is -0.0042315405712543
# Model is not converging.  Current: 1772.9367562060531 is not greater than 1772.9367915043767. Delta is -3.5298323609822546e-05
# Model is not converging.  Current: 1721.133163808797 is not greater than 1721.133286965528. Delta is -0.00012315673097873514
# Model is not converging.  Current: 1746.1412575462562 is not greater than 1746.1412693879422. Delta is -1.1841686045954702e-05
# Model is not converging.  Current: 1727.4475505756243 is not greater than 1727.4478318386527. Delta is -0.0002812630284552142
# Model is not converging.  Current: 1763.0817577003227 is not greater than 1763.0820783735649. Delta is -0.000320673242185876
# Model is not converging.  Current: 2648.5226310651537 is not greater than 2648.5227392703337. Delta is -0.00010820517991305678
# Model is not converging.  Current: 2802.535040743785 is not greater than 2802.5390312405284. Delta is -0.003990496743426775
# Model is not converging.  Current: 2682.9904382888412 is not greater than 2682.9911419531677. Delta is -0.000703664326465514
# Model is not converging.  Current: 2661.906169007188 is not greater than 2661.9072469710086. Delta is -0.001077963820534933
# Model is not converging.  Current: 2786.954911301394 is not greater than 2786.9611074247478. Delta is -0.0061961233536749205
# Model is not converging.  Current: 2637.3998093355867 is not greater than 2637.39999995416. Delta is -0.0001906185734696919
# Model is not converging.  Current: 2643.7844481960533 is not greater than 2643.785900889568. Delta is -0.0014526935146932374
# Model is not converging.  Current: 2802.547436608072 is not greater than 2802.5507790650836. Delta is -0.0033424570115130336
# Model is not converging.  Current: 2653.565121847962 is not greater than 2653.5657363615687. Delta is -0.0006145136067061685
# Model is not converging.  Current: 2798.057577525417 is not greater than 2798.057603482733. Delta is -2.595731621113373e-05
# Model is not converging.  Current: 2797.0251549182944 is not greater than 2797.0252057726984. Delta is -5.085440398033825e-05
# Model is not converging.  Current: 2684.0733672645997 is not greater than 2684.07398938386. Delta is -0.0006221192602424708
# Model is not converging.  Current: 2798.05319361489 is not greater than 2798.053383540611. Delta is -0.00018992572086062864
# Model is not converging.  Current: 2647.798978994006 is not greater than 2647.7990436017058. Delta is -6.460769964178326e-05
# Model is not converging.  Current: 2637.3406969802045 is not greater than 2637.3419690420405. Delta is -0.0012720618360617664
# Model is not converging.  Current: 2802.6614628093 is not greater than 2802.6616391919. Delta is -0.00017638260032981634
# Model is not converging.  Current: 2798.057345604817 is not greater than 2798.057345798046. Delta is -1.932289706019219e-07
# Model is not converging.  Current: 2661.3304283373195 is not greater than 2661.3304318976866. Delta is -3.56036707671592e-06
# Model is not converging.  Current: 2805.9235686418765 is not greater than 2805.924623774183. Delta is -0.0010551323066465557
# Model is not converging.  Current: 2632.202836369197 is not greater than 2632.205223995668. Delta is -0.0023876264708633244
# Model is not converging.  Current: 2642.9637792962953 is not greater than 2642.9645197086074. Delta is -0.0007404123120977602
# Model is not converging.  Current: 2664.8850553511843 is not greater than 2664.8852502245954. Delta is -0.00019487341114654555
# Model is not converging.  Current: 2663.9658204851694 is not greater than 2663.9661717139247. Delta is -0.00035122875533488696
# Model is not converging.  Current: 2805.949781547069 is not greater than 2805.9551699490935. Delta is -0.0053884020244368
# Model is not converging.  Current: 2628.826269791625 is not greater than 2628.8272632923063. Delta is -0.0009935006814885128
# Model is not converging.  Current: 2663.963955378199 is not greater than 2663.9639912174775. Delta is -3.5839278552884934e-05
# Model is not converging.  Current: 2798.055246410287 is not greater than 2798.0553492690383. Delta is -0.00010285875123372534
# Model is not converging.  Current: 2805.920304159456 is not greater than 2805.920598749576. Delta is -0.00029459012012011954
# Model is not converging.  Current: 2610.780473593046 is not greater than 2610.7805465713614. Delta is -7.297831552932621e-05
# Model is not converging.  Current: 2682.9909684893623 is not greater than 2682.9911918690427. Delta is -0.00022337968039209954
# Model is not converging.  Current: 2687.222631385288 is not greater than 2687.2239609732746. Delta is -0.0013295879866745963
# Model is not converging.  Current: 2649.2143015727706 is not greater than 2649.2160410952124. Delta is -0.0017395224417668942
# Model is not converging.  Current: 2805.975052762124 is not greater than 2805.975582438597. Delta is -0.0005296764729791903
# Model is not converging.  Current: 2663.9630081466307 is not greater than 2663.963417424059. Delta is -0.00040927742838903214
# Model is not converging.  Current: 2628.819224628742 is not greater than 2628.822452394556. Delta is -0.003227765813790029
# Model is not converging.  Current: 2805.973344998508 is not greater than 2805.9753580240263. Delta is -0.00201302551840854
# Model is not converging.  Current: 2796.912152377205 is not greater than 2796.912165700393. Delta is -1.3323187886271626e-05
# Model is not converging.  Current: 2798.0526063873945 is not greater than 2798.052694837311. Delta is -8.844991634759936e-05
# Model is not converging.  Current: 2795.505516613845 is not greater than 2795.5061258838327. Delta is -0.0006092699877626728
# Model is not converging.  Current: 2661.9266779408795 is not greater than 2661.931459426519. Delta is -0.004781485639341554
# Model is not converging.  Current: 2748.3345303317055 is not greater than 2748.3348662857693. Delta is -0.00033595406375752646
# Model is not converging.  Current: 2805.9336282180807 is not greater than 2805.9351355910408. Delta is -0.0015073729600771912
# Model is not converging.  Current: 2649.217161597965 is not greater than 2649.2172994413745. Delta is -0.00013784340944766882
# Model is not converging.  Current: 2682.990915005338 is not greater than 2682.9911502077966. Delta is -0.00023520245849795174
# Model is not converging.  Current: 2805.9468447557206 is not greater than 2805.948466953319. Delta is -0.0016221975984080927
# Model is not converging.  Current: 2699.865475703292 is not greater than 2699.867753588053. Delta is -0.0022778847610425146
# Model is not converging.  Current: 2797.6734503931702 is not greater than 2797.6735751461965. Delta is -0.00012475302628445206
# Model is not converging.  Current: 2687.219669760057 is not greater than 2687.220844734286. Delta is -0.001174974228888459
# Model is not converging.  Current: 2653.4761911842043 is not greater than 2653.4768645178297. Delta is -0.0006733336254001188
# Model is not converging.  Current: 2802.5242094401788 is not greater than 2802.5253035280207. Delta is -0.0010940878419205546
# Model is not converging.  Current: 2805.953558216691 is not greater than 2805.9618242548463. Delta is -0.008266038155397837
# Model is not converging.  Current: 2805.951695287148 is not greater than 2805.9580112559024. Delta is -0.006315968754279311
# Model is not converging.  Current: 2798.0568456628225 is not greater than 2798.056926615079. Delta is -8.095225666693295e-05
# Model is not converging.  Current: 2667.8586236396472 is not greater than 2667.859158629449. Delta is -0.0005349898019630928
# Model is not converging.  Current: 2663.158061822285 is not greater than 2663.1580874670876. Delta is -2.564480246292078e-05
# Model is not converging.  Current: 2661.07895936304 is not greater than 2661.079457380664. Delta is -0.0004980176236131229
# Model is not converging.  Current: 2610.7628195654725 is not greater than 2610.767508626058. Delta is -0.004689060585405969
# Model is not converging.  Current: 1756.3399037380725 is not greater than 1756.3402335234916. Delta is -0.000329785419125983
# Model is not converging.  Current: 1855.1050851680925 is not greater than 1855.1052683807193. Delta is -0.00018321262678000494
# Model is not converging.  Current: 1866.1341201846435 is not greater than 1866.146827858801. Delta is -0.012707674157582005
# Model is not converging.  Current: 1756.0006180774085 is not greater than 1756.0011225318801. Delta is -0.0005044544716383825
# Model is not converging.  Current: 1846.883307837322 is not greater than 1846.8855524574142. Delta is -0.0022446200921422133
# Model is not converging.  Current: 1779.1519999135378 is not greater than 1779.1520373398187. Delta is -3.7426280869112816e-05
# Model is not converging.  Current: 1855.6808484109556 is not greater than 1855.6905713906262. Delta is -0.009722979670641507
# Model is not converging.  Current: 1790.0773523048117 is not greater than 1790.0831399542722. Delta is -0.0057876494604443
# Model is not converging.  Current: 1663.0742833117972 is not greater than 1663.091390994486. Delta is -0.017107682688674686
# Model is not converging.  Current: 1801.9332214306435 is not greater than 1801.935351209959. Delta is -0.00212977931550995
# Model is not converging.  Current: 1687.606813314284 is not greater than 1687.6122297151226. Delta is -0.00541640083861239
# Model is not converging.  Current: 1850.8002549128864 is not greater than 1850.8006929167643. Delta is -0.00043800387788905937
# Model is not converging.  Current: 1709.6280811312618 is not greater than 1709.635078005937. Delta is -0.006996874675223808
# Model is not converging.  Current: 1538.3903336241528 is not greater than 1555.0679886469834. Delta is -16.67765502283055
# Model is not converging.  Current: 1799.0827511133755 is not greater than 1799.0857729195272. Delta is -0.0030218061517643946
# Model is not converging.  Current: 1845.8483734116808 is not greater than 1845.8486297018333. Delta is -0.00025629015249251097
# Model is not converging.  Current: 1764.4107510108158 is not greater than 1764.4182281482817. Delta is -0.007477137465912165
# Model is not converging.  Current: 1722.467403645424 is not greater than 1722.4722707545607. Delta is -0.0048671091367396
# Model is not converging.  Current: 1789.2285735044427 is not greater than 1789.228677769522. Delta is -0.00010426507924421458
# Model is not converging.  Current: 1749.5799437477672 is not greater than 1749.5925830352846. Delta is -0.012639287517458797
# Model is not converging.  Current: 1860.427448376543 is not greater than 1860.4274634551027. Delta is -1.5078559727044194e-05
# Model is not converging.  Current: 1771.7722221500626 is not greater than 1771.7734357995505. Delta is -0.0012136494879086968
# Model is not converging.  Current: 1855.7789166667608 is not greater than 1855.7973326168997. Delta is -0.018415950138887638
# Model is not converging.  Current: 1850.7087300071826 is not greater than 1850.7114478216956. Delta is -0.002717814513061967
# Model is not converging.  Current: 1793.8538690649825 is not greater than 1793.8604800588994. Delta is -0.006610993916865482
# Model is not converging.  Current: 1865.2776196202803 is not greater than 1865.2786201878255. Delta is -0.0010005675451338902
# Model is not converging.  Current: 1787.419602486991 is not greater than 1787.4198094520975. Delta is -0.00020696510659945488
# Model is not converging.  Current: 1791.108833627959 is not greater than 1791.1090644990225. Delta is -0.00023087106342245534
# Model is not converging.  Current: 1824.0637856065246 is not greater than 1824.0639225364505. Delta is -0.0001369299259295076
# Model is not converging.  Current: 1788.9847501728773 is not greater than 1788.9854270856836. Delta is -0.0006769128062842356
# Model is not converging.  Current: 1814.2727747476233 is not greater than 1814.291145508009. Delta is -0.01837076038577834
# Model is not converging.  Current: 1825.5742979973359 is not greater than 1825.5789535386116. Delta is -0.0046555412757243175
# Model is not converging.  Current: 1866.9431071877602 is not greater than 1866.9457892531802. Delta is -0.0026820654200037097
# Model is not converging.  Current: 1796.6638720462677 is not greater than 1796.6673060097035. Delta is -0.0034339634357820614
# Model is not converging.  Current: 1798.0221692838818 is not greater than 1798.0235417811516. Delta is -0.0013724972698128113
# Model is not converging.  Current: 1851.8344885977197 is not greater than 1851.8347636671754. Delta is -0.0002750694557107636
# Model is not converging.  Current: 1802.5132747408366 is not greater than 1802.5176773184432. Delta is -0.004402577606697378
# Model is not converging.  Current: 1737.6000811806225 is not greater than 1737.6041708610342. Delta is -0.004089680411652807
# Model is not converging.  Current: 1817.1439636127936 is not greater than 1817.152374474624. Delta is -0.008410861830270733
# Model is not converging.  Current: 2652.7024116933535 is not greater than 2652.7025277523403. Delta is -0.00011605898680500104
# Model is not converging.  Current: 2831.8267492436594 is not greater than 2831.835572913183. Delta is -0.008823669523735589
# Model is not converging.  Current: 2681.1713595140805 is not greater than 2681.171696175303. Delta is -0.0003366612227182486
# Model is not converging.  Current: 2890.454126727666 is not greater than 2890.4559863484246. Delta is -0.0018596207587506797
# Model is not converging.  Current: 2839.444675402963 is not greater than 2839.4595923302936. Delta is -0.014916927330432372
# Model is not converging.  Current: 2648.0839540466964 is not greater than 2648.0839577847796. Delta is -3.738083250937052e-06
# Model is not converging.  Current: 2834.3455019363164 is not greater than 2834.3527030379046. Delta is -0.007201101588179881
# Model is not converging.  Current: 2832.6437578448395 is not greater than 2832.6438657087892. Delta is -0.00010786394977913005
# Model is not converging.  Current: 2814.0079018841648 is not greater than 2814.0171244311714. Delta is -0.009222547006629611
# Model is not converging.  Current: 2877.1686035882612 is not greater than 2877.168766101185. Delta is -0.00016251292390734307
# Model is not converging.  Current: 2653.851228223811 is not greater than 2653.85135623489. Delta is -0.0001280110786865407
# Model is not converging.  Current: 2675.9445034968285 is not greater than 2675.94654050489. Delta is -0.00203700806150664
# Model is not converging.  Current: 2826.7203115213524 is not greater than 2826.72047736539. Delta is -0.0001658440373830672
# Model is not converging.  Current: 2708.135602622634 is not greater than 2708.1360586715577. Delta is -0.0004560489237519505
# Model is not converging.  Current: 2656.376349134502 is not greater than 2656.376754526. Delta is -0.0004053914976793749
# Model is not converging.  Current: 2828.972276935081 is not greater than 2828.9779450387164. Delta is -0.0056681036353438685
# Model is not converging.  Current: 2837.740740048989 is not greater than 2837.747855748401. Delta is -0.007115699411770038
# Model is not converging.  Current: 2837.591530273099 is not greater than 2837.594012893479. Delta is -0.0024826203798511415
# Model is not converging.  Current: 2890.4950504102226 is not greater than 2890.5138823593616. Delta is -0.018831949138984783
# Model is not converging.  Current: 2668.642903055831 is not greater than 2668.644671156104. Delta is -0.0017681002727840678
# Model is not converging.  Current: 2662.629437623221 is not greater than 2662.629708726233. Delta is -0.00027110301198263187
# Model is not converging.  Current: 2678.605222573183 is not greater than 2678.605532291744. Delta is -0.00030971856131145614
# Model is not converging.  Current: 2657.2849939982725 is not greater than 2657.285763702722. Delta is -0.0007697044493397698
# Model is not converging.  Current: 2848.724832560095 is not greater than 2848.7279949229805. Delta is -0.0031623628856323194
# Model is not converging.  Current: 2830.7472062639563 is not greater than 2830.7476119030966. Delta is -0.0004056391403537418
# Model is not converging.  Current: 2917.9023909122675 is not greater than 2917.904185801172. Delta is -0.0017948889044419047
# Model is not converging.  Current: 2837.0856316123713 is not greater than 2837.085823503014. Delta is -0.00019189064278180012
# Model is not converging.  Current: 2695.398710213863 is not greater than 2695.4003220405175. Delta is -0.0016118266544253856
# Model is not converging.  Current: 2807.0973877809524 is not greater than 2807.098192891349. Delta is -0.0008051103964135109
# Model is not converging.  Current: 2694.3396049006315 is not greater than 2694.340160554722. Delta is -0.0005556540904763096
# Model is not converging.  Current: 2704.259436931475 is not greater than 2704.259491933412. Delta is -5.500193674379261e-05
# Model is not converging.  Current: 2726.037641941799 is not greater than 2726.0418196409996. Delta is -0.004177699200681673
# Model is not converging.  Current: 2377.947637716393 is not greater than 2401.698889949483. Delta is -23.751252233090327
# Model is not converging.  Current: 2795.025509461127 is not greater than 2795.030624226903. Delta is -0.005114765775942942
# Model is not converging.  Current: 2681.929260651798 is not greater than 2681.929548760108. Delta is -0.00028810831008740934
# Model is not converging.  Current: 2839.0184581428484 is not greater than 2839.0185499956974. Delta is -9.185284898194368e-05
# Model is not converging.  Current: 2809.13493627168 is not greater than 2809.135013783863. Delta is -7.751218299745233e-05
# Model is not converging.  Current: 2837.244442387417 is not greater than 2837.2492605101484. Delta is -0.0048181227311943076
# Model is not converging.  Current: 2698.1972923405456 is not greater than 2698.197602486136. Delta is -0.000310145590447064
# Model is not converging.  Current: 2814.4999645157095 is not greater than 2814.5000259041813. Delta is -6.138847174952389e-05
# Model is not converging.  Current: 2877.3752700294885 is not greater than 2877.3902345788397. Delta is -0.014964549351134337
# Model is not converging.  Current: 2827.3365231815787 is not greater than 2827.336967248317. Delta is -0.0004440667380549712
# Model is not converging.  Current: 2852.2104476628633 is not greater than 2852.212879248839. Delta is -0.0024315859755006386
# Model is not converging.  Current: 2855.996754955138 is not greater than 2856.0042915648996. Delta is -0.007536609761700674
# Model is not converging.  Current: 2380.6706270422947 is not greater than 2383.462953836223. Delta is -2.7923267939281686
# Model is not converging.  Current: 2836.8537739217404 is not greater than 2836.857519738528. Delta is -0.003745816787613876
# Model is not converging.  Current: 2695.4786113665414 is not greater than 2695.4788732046054. Delta is -0.0002618380640342366
# Model is not converging.  Current: 1766.040111251849 is not greater than 1766.0466072399258. Delta is -0.006495988076721915
# Model is not converging.  Current: 1841.3541182467436 is not greater than 1841.356462359373. Delta is -0.0023441126293164416
# Model is not converging.  Current: 1812.7103032416207 is not greater than 1812.7140758622115. Delta is -0.003772620590780207
# ...
# Model is not converging.  Current: 1776.2512315523154 is not greater than 1776.2512910347782. Delta is -5.94824628024071e-05
# Model is not converging.  Current: 1815.6969657012062 is not greater than 1815.6973607708467. Delta is -0.0003950696404899645
# Model is not converging.  Current: 1874.2255138073479 is not greater than 1874.2296430642582. Delta is -0.004129256910346157
# Model is not converging.  Current: 1878.865520741181 is not greater than 1878.866064456887. Delta is -0.0005437157060441677
# Model is not converging.  Current: 1828.8196149625662 is not greater than 1828.819925963848. Delta is -0.0003110012817160168
# Model is not converging.  Current: 1906.655208085124 is not greater than 1906.6558265590681. Delta is -0.0006184739440868725
# Model is not converging.  Current: 1805.4650203093574 is not greater than 1805.4745797867104. Delta is -0.00955947735292284
# Model is not converging.  Current: 1863.4464228617476 is not greater than 1863.4466260825648. Delta is -0.0002032208171840466
# Model is not converging.  Current: 1886.945536238052 is not greater than 1886.9455470144624. Delta is -1.0776410363178002e-05
# Model is not converging.  Current: 1699.1067334609822 is not greater than 1699.1077861778206. Delta is -0.0010527168383305252
# Model is not converging.  Current: 1864.2921652732853 is not greater than 1864.292726065056. Delta is -0.0005607917707948218
# Model is not converging.  Current: 1893.6032620777191 is not greater than 1893.6041381433688. Delta is -0.0008760656496633601
# Model is not converging.  Current: 1878.2763619908712 is not greater than 1878.3117381338502. Delta is -0.03537614297897562
# Model is not converging.  Current: 1689.751124694187 is not greater than 1706.747033613668. Delta is -16.995908919481053
# Model is not converging.  Current: 1798.4146376118067 is not greater than 1798.419858814287. Delta is -0.005221202480242937
# Model is not converging.  Current: 2725.1712779532463 is not greater than 2725.1805839246185. Delta is -0.009305971372214117
# Model is not converging.  Current: 2700.4658679315794 is not greater than 2700.4698181587187. Delta is -0.003950227139284834
# Model is not converging.  Current: 2832.988910436238 is not greater than 2832.988929057969. Delta is -1.862173121480737e-05
# Model is not converging.  Current: 2693.2794226695814 is not greater than 2693.2799458998447. Delta is -0.0005232302632975916
# Model is not converging.  Current: 2400.8399072564484 is not greater than 2412.6546206823073. Delta is -11.814713425858827
# Model is not converging.  Current: 2920.9553551745394 is not greater than 2920.961579660152. Delta is -0.006224485612619901
# Model is not converging.  Current: 2837.8946068175237 is not greater than 2837.895254159021. Delta is -0.00064734149736978
# Model is not converging.  Current: 2714.566879591296 is not greater than 2714.5703893539535. Delta is -0.003509762657358806
# Model is not converging.  Current: 2836.115615020206 is not greater than 2836.11975042084. Delta is -0.0041354006339133775
# Model is not converging.  Current: 2867.871218074812 is not greater than 2867.8768002633287. Delta is -0.005582188516655151
# Model is not converging.  Current: 2842.765947240803 is not greater than 2842.767844846379. Delta is -0.0018976055757775612
# Model is not converging.  Current: 2821.064261018774 is not greater than 2821.0654054998254. Delta is -0.001144481051596813
# Model is not converging.  Current: 2691.428493851536 is not greater than 2691.4290777767296. Delta is -0.0005839251934958156
# Model is not converging.  Current: 2870.3990360736643 is not greater than 2870.403257989599. Delta is -0.004221915934522258
# Model is not converging.  Current: 2736.4658059438193 is not greater than 2736.466068285776. Delta is -0.00026234195684082806
# Model is not converging.  Current: 2912.850790906819 is not greater than 2912.8508067308294. Delta is -1.5824010461074067e-05
# Model is not converging.  Current: 2867.0723904285696 is not greater than 2867.0732273374238. Delta is -0.0008369088541257952
# Model is not converging.  Current: 2942.8903203101345 is not greater than 2942.8923950975127. Delta is -0.002074787378205656
# Model is not converging.  Current: 2888.187708622679 is not greater than 2888.188063569485. Delta is -0.00035494680605552276
# Model is not converging.  Current: 2703.7005262626503 is not greater than 2703.7055925924187. Delta is -0.005066329768396827
# Model is not converging.  Current: 2687.8696538181034 is not greater than 2687.870956964133. Delta is -0.001303146029385971
# Model is not converging.  Current: 2820.558296443151 is not greater than 2820.5583484537356. Delta is -5.2010584568051854e-05
# Model is not converging.  Current: 2903.7375372881293 is not greater than 2903.756299764417. Delta is -0.018762476287520258
# Model is not converging.  Current: 2845.361381263208 is not greater than 2845.363207473659. Delta is -0.0018262104508721677
# Model is not converging.  Current: 2917.390425303444 is not greater than 2917.390510987725. Delta is -8.568428120270255e-05
# Model is not converging.  Current: 2689.1666876852823 is not greater than 2690.7700237773165. Delta is -1.6033360920341693
# Model is not converging.  Current: 2852.5128803146076 is not greater than 2852.52628760291. Delta is -0.013407288302460074
# Model is not converging.  Current: 2738.661304422679 is not greater than 2738.6622535418805. Delta is -0.0009491192013229011
# Model is not converging.  Current: 2838.8171443654537 is not greater than 2838.817172363967. Delta is -2.7998513360216748e-05
# Model is not converging.  Current: 2639.26261472557 is not greater than 2658.8041117236353. Delta is -19.541496998065213
# Model is not converging.  Current: 2852.4523842610392 is not greater than 2852.453718246869. Delta is -0.001333985829660378
# Model is not converging.  Current: 2931.594212606585 is not greater than 2931.595050233158. Delta is -0.0008376265727747523
# Model is not converging.  Current: 2713.259707349383 is not greater than 2713.2609668277464. Delta is -0.0012594783634085616
# Model is not converging.  Current: 2735.0469704022817 is not greater than 2735.04815208254. Delta is -0.0011816802584689867
# Model is not converging.  Current: 2836.895196365204 is not greater than 2836.89692342707. Delta is -0.0017270618659495085
# Model is not converging.  Current: 2643.712886399762 is not greater than 2663.453530879847. Delta is -19.740644480085393
# Model is not converging.  Current: 2848.7211908997406 is not greater than 2848.721626013222. Delta is -0.00043511348121683113
# Model is not converging.  Current: 2869.0573945847573 is not greater than 2869.058963004289. Delta is -0.0015684195318499405
# Model is not converging.  Current: 2900.1750634443933 is not greater than 2900.175148063101. Delta is -8.461870766041102e-05
# Model is not converging.  Current: 2903.570765200797 is not greater than 2903.5854926738166. Delta is -0.014727473019775061
# Model is not converging.  Current: 2713.170986631291 is not greater than 2713.1729298998157. Delta is -0.001943268524883024
# Model is not converging.  Current: 2728.0783417284874 is not greater than 2728.079005029543. Delta is -0.0006633010557379748
# Model is not converging.  Current: 2708.915668654256 is not greater than 2708.91715498984. Delta is -0.0014863355841043813
# Model is not converging.  Current: 2652.313081626565 is not greater than 2671.3521589264387. Delta is -19.039077299873952
# Model is not converging.  Current: 2680.874491335194 is not greater than 2680.8745431969905. Delta is -5.1861796691810014e-05
# Model is not converging.  Current: 2490.119687443232 is not greater than 2508.285094518708. Delta is -18.16540707547574
# Model is not converging.  Current: 2879.943233757755 is not greater than 2879.9447365216747. Delta is -0.0015027639196887321
# Model is not converging.  Current: 2898.1456269730866 is not greater than 2898.1520174411426. Delta is -0.006390468055997189
# Model is not converging.  Current: 2842.516742963285 is not greater than 2842.5608172233815. Delta is -0.04407426009629489
# Model is not converging.  Current: 2704.6274980498606 is not greater than 2729.024208714804. Delta is -24.396710664943384
# Model is not converging.  Current: 1886.3925298382117 is not greater than 1886.3934439704024. Delta is -0.0009141321907009115
# Model is not converging.  Current: 1769.4883686720668 is not greater than 1792.9315192015438. Delta is -23.443150529476952
# Model is not converging.  Current: 1909.6912201883624 is not greater than 1909.6918029996032. Delta is -0.0005828112407471053
# Model is not converging.  Current: 1825.0437679134604 is not greater than 1825.0467340875707. Delta is -0.0029661741102700034
# Model is not converging.  Current: 1881.266372015818 is not greater than 1881.2692145986869. Delta is -0.0028425828688796173
# Model is not converging.  Current: 1762.5034830411948 is not greater than 1772.9109139594284. Delta is -10.407430918233558
# Model is not converging.  Current: 1999.8216700614528 is not greater than 1999.822403684529. Delta is -0.0007336230762575724
# Model is not converging.  Current: 1762.2434224714623 is not greater than 1762.250019529461. Delta is -0.006597057998760647
# Model is not converging.  Current: 1828.7322187224552 is not greater than 1828.7353746728284. Delta is -0.0031559503731841687
# Model is not converging.  Current: 1836.0801548276484 is not greater than 1836.0802165309324. Delta is -6.17032840182219e-05
# Model is not converging.  Current: 1970.5537171391252 is not greater than 1970.5567944028182. Delta is -0.00307726369305783
# Model is not converging.  Current: 1673.7824707925752 is not greater than 1694.7726484044147. Delta is -20.9901776118395
# Model is not converging.  Current: 1887.8901137036692 is not greater than 1887.8931370771777. Delta is -0.003023373508540317
# Model is not converging.  Current: 1816.0538071429114 is not greater than 1816.0542655708534. Delta is -0.0004584279420214443
# Model is not converging.  Current: 1960.814287591896 is not greater than 1960.8151205446004. Delta is -0.0008329527045134455
# Model is not converging.  Current: 1898.0900635602657 is not greater than 1898.0921981485849. Delta is -0.00213458831922253
# Model is not converging.  Current: 1926.3035760225962 is not greater than 1926.3044354390527. Delta is -0.0008594164564783568
# Model is not converging.  Current: 1856.9489258649635 is not greater than 1856.949608134233. Delta is -0.0006822692694186117
# Model is not converging.  Current: 1975.6971354839677 is not greater than 1975.6972644409227. Delta is -0.00012895695499537396
# Model is not converging.  Current: 1987.7788248509453 is not greater than 1987.779039181176. Delta is -0.00021433023061945278
# Model is not converging.  Current: 1818.89606018808 is not greater than 1819.535544244733. Delta is -0.6394840566531457
# Model is not converging.  Current: 1929.460799168677 is not greater than 1929.4608084588745. Delta is -9.290197340305895e-06
# Model is not converging.  Current: 1930.7981120080035 is not greater than 1930.7982556893328. Delta is -0.00014368132929121202
# Model is not converging.  Current: 1914.565262397516 is not greater than 1914.5657321235008. Delta is -0.0004697259846579982
# Model is not converging.  Current: 1876.1395020897162 is not greater than 1876.140240124831. Delta is -0.000738035114864033
# Model is not converging.  Current: 1660.9223210907376 is not greater than 1680.6389839448266. Delta is -19.71666285408901
# Model is not converging.  Current: 1750.2788774659941 is not greater than 1757.8353081297819. Delta is -7.556430663787751
# Model is not converging.  Current: 1859.4214142226663 is not greater than 1859.462382658515. Delta is -0.04096843584875387
# Model is not converging.  Current: 1798.6015044049964 is not greater than 1798.6049715307286. Delta is -0.003467125732186105
# Model is not converging.  Current: 1815.4751459596632 is not greater than 1815.4752070796956. Delta is -6.112003234193253e-05
# Model is not converging.  Current: 1870.3755209610645 is not greater than 1870.378012422455. Delta is -0.0024914613904911675
# Model is not converging.  Current: 1882.6610279712304 is not greater than 1882.6611542995595. Delta is -0.00012632832908821
# Model is not converging.  Current: 1940.1175087791537 is not greater than 1940.1179677683144. Delta is -0.0004589891607338359
# Model is not converging.  Current: 1873.4195232549853 is not greater than 1873.4196286218678. Delta is -0.00010536688250795123
# Model is not converging.  Current: 1831.5504663808904 is not greater than 1831.5510296517486. Delta is -0.0005632708582652413
# Model is not converging.  Current: 1917.273472761081 is not greater than 1917.274576079683. Delta is -0.0011033186019631103
# Model is not converging.  Current: 1924.927522433193 is not greater than 1924.9304513850786. Delta is -0.0029289518856785435
# Model is not converging.  Current: 1896.5261424537437 is not greater than 1896.5265764039123. Delta is -0.0004339501685990399
# Model is not converging.  Current: 1893.9759803439442 is not greater than 1893.9815528468541. Delta is -0.005572502909899413
# Model is not converging.  Current: 1734.160883359657 is not greater than 1749.946373068584. Delta is -15.785489708927116
# Model is not converging.  Current: 1949.4465610728062 is not greater than 1949.447219574217. Delta is -0.0006585014107258758
# Model is not converging.  Current: 1852.1545796291684 is not greater than 1852.1547971614227. Delta is -0.00021753225428255973
# Model is not converging.  Current: 1802.8903816954978 is not greater than 1802.8971488502693. Delta is -0.006767154771523565
# Model is not converging.  Current: 1950.6256582171327 is not greater than 1950.6360244424627. Delta is -0.010366225330017187
# Model is not converging.  Current: 1728.8075597796467 is not greater than 1728.8076469188272. Delta is -8.713918055036629e-05
# Model is not converging.  Current: 1783.6315976264514 is not greater than 1783.6336229065078. Delta is -0.0020252800563866913
# Model is not converging.  Current: 1919.1182668284632 is not greater than 1919.1183587844635. Delta is -9.195600023303996e-05
# Model is not converging.  Current: 1925.411000629244 is not greater than 1925.4617763136487. Delta is -0.05077568440469804
# Model is not converging.  Current: 1681.2371401681469 is not greater than 1681.2389578664358. Delta is -0.0018176982889599458
# Model is not converging.  Current: 1865.6095505802712 is not greater than 1865.609813976569. Delta is -0.000263396297896179
# Model is not converging.  Current: 1903.9891960509133 is not greater than 1903.9904092687111. Delta is -0.001213217797840116
# Model is not converging.  Current: 1955.280095261841 is not greater than 1955.2802867318196. Delta is -0.00019146997851748893
# Model is not converging.  Current: 1981.968059969104 is not greater than 1981.9858909033044. Delta is -0.01783093420044679
# Model is not converging.  Current: 1927.337185587355 is not greater than 1927.3379684626213. Delta is -0.0007828752663954219
# Model is not converging.  Current: 1927.761977554611 is not greater than 1927.7673776623162. Delta is -0.005400107705327173
# Model is not converging.  Current: 1903.6876398362822 is not greater than 1903.6960619945175. Delta is -0.008422158235362076
# Model is not converging.  Current: 1949.4412049967616 is not greater than 1949.4428830460458. Delta is -0.0016780492842372041
# Model is not converging.  Current: 1911.7265411778899 is not greater than 1911.729225018936. Delta is -0.002683841046064117
# Model is not converging.  Current: 1857.1584102188474 is not greater than 1880.450273965941. Delta is -23.291863747093657
#  n_components  params  obs_per_param        BIC  OOS_ll_per_point
#             2      21           35.4 -4365.4537            2.5708
#             3      35           21.2 -4894.2318            2.8727
#             4      51           14.6 -5146.1294            3.1245
#             5      69           10.8 -5155.7948            3.1439
#             6      89            8.3 -5247.4477            3.5219
#             7     111            6.7 -5151.9845            3.6227
#
# BIC argmin  -> K = 6
# OOS argmax  -> K = 7

# %% [markdown]
# ### Choice of K
#
# At `r = 3` the two criteria **agree** on K=6. This is the justification the original notebook
# lacked: with the contaminated split, OOS peaked at K=5 while BIC chose K=6, and the claim that
# both selected 6 was not supported. Repairing the split removes the conflict.
#
# At `r = 4` the criteria disagree (BIC 6, OOS 7) and the OOS curve is non-monotone, a symptom of
# an unstable fourth coordinate. Note $\lambda_3/\lambda_4 \approx 0.95$, so coordinates 3 and 4
# are near-degenerate; splitting them is arbitrary, which is a reason for caution about r=4, but
# the honest OOS is what decides it. Six states at 8.3 observations per parameter remains a real
# constraint and is stated as a limitation rather than explained away.

# %%
chosen_K = 6
model = models[chosen_K]
states = model.predict(Psi)
A = model.transmat_

eigvals,eigvecs = np.linalg.eig(A.T)
pi = np.real(eigvecs[:, np.argmin(np.abs(eigvals-1))]); pi/=pi.sum()
print("stationary distribution:", np.round(pi,4))
print("state occupancy:", {f"s{i}": int((states==i).sum()) for i in range(chosen_K)})
print("self-transition probs:", np.round(np.diag(A),4))

fig,ax=plt.subplots(figsize=(6,5)); im=ax.imshow(A,aspect="auto")
for i in range(chosen_K):
    for j in range(chosen_K): ax.text(j,i,f"{A[i,j]:.2f}",ha="center",va="center",fontsize=8)
fig.colorbar(im,ax=ax,label="transition probability")
ax.set_title("Transition matrix"); ax.set_xlabel("to state"); ax.set_ylabel("from state")
plt.tight_layout(); plt.show()
# Out:
# stationary distribution: [0.0278 0.1658 0.2751 0.197  0.2209 0.1133]
# state occupancy: {'s0': 19, 's1': 132, 's2': 185, 's3': 135, 's4': 167, 's5': 105}
# self-transition probs: [0.8871 0.8903 0.9061 0.9319 0.8819 0.9413]

# %%
fig,ax=plt.subplots(figsize=(13,5))
ax.plot(dates,states,lw=1.6,color="#1f77b4",label="Viterbi state")
ymin,ymax=ax.get_ylim()
ax.fill_between(dates,ymin,ymax,where=(df["recession"].values==1),color="gray",
                alpha=.45,label="NBER recession",edgecolor="none")
ax.set_ylim(ymin,ymax); ax.set_yticks(range(chosen_K))
ax.xaxis.set_major_locator(mdates.AutoDateLocator()); ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
fig.autofmt_xdate(); ax.grid(axis="y",ls="--",alpha=.5)
ax.spines[["top","right"]].set_visible(False); ax.legend(loc="upper left")
ax.set_title("Viterbi path vs NBER recessions",fontweight="bold")
plt.tight_layout(); plt.show()

# %% [markdown]
# ### Macro profile of each state (interpretable units)

# %%
macro=obs_df.copy(); macro["state"]=states
cols=["UNRATE","FEDFUNDS","CPIAUCSL","S&P 500","HOUST"]
state_means=macro.groupby("state")[cols].mean()
print(state_means.round(4).to_string())
sm_z=(state_means-state_means.mean(0))/state_means.std(0)
fig,ax=plt.subplots(figsize=(9,4)); im=ax.imshow(sm_z,aspect="auto",cmap="RdBu_r",vmin=-2,vmax=2)
ax.set_xticks(range(len(cols))); ax.set_xticklabels(cols,rotation=20,ha="right")
ax.set_yticks(range(len(sm_z))); ax.set_yticklabels([f"State {i}" for i in sm_z.index])
for i in range(sm_z.shape[0]):
    for j in range(sm_z.shape[1]): ax.text(j,i,f"{sm_z.iloc[i,j]:.1f}",ha="center",va="center",fontsize=8)
fig.colorbar(im,ax=ax,label="state mean (sd from cross-state mean)")
ax.set_title("Macroeconomic profile of each HMM state")
plt.tight_layout(); plt.show()
# Out:
#        UNRATE  FEDFUNDS  CPIAUCSL  S&P 500   HOUST
# state
# 0      9.0316   -0.1779    0.0005  -0.0115  6.5081
# 1      5.2833    0.0157    0.0001   0.0058  7.3556
# 2      6.2176   -0.0312    0.0001   0.0102  7.1034
# 3      7.0985   -0.2336   -0.0002   0.0045  7.1287
# 4      4.9934    0.1080   -0.0001   0.0074  7.2729
# 5      5.1562    0.1973    0.0000   0.0017  7.4370

# %% [markdown]
# ## Task IV.2 — validation against NBER

# %%
res=[{"state":s,"cohens_kappa":cohen_kappa_score(df["recession"].values,(states==s).astype(int))}
     for s in np.unique(states)]
kappa_results=pd.DataFrame(res).sort_values("cohens_kappa",ascending=False)
print(kappa_results.round(4).to_string(index=False))
crisis_state=int(kappa_results.iloc[0]["state"])
print("\nbest recession-matching state:",crisis_state)
# Out:
#  state  cohens_kappa
#      3        0.4439
#      0        0.1794
#      4       -0.0908
#      2       -0.1395
#      1       -0.1409
#      5       -0.1531
#
# best recession-matching state: 3

# %%
def report(y_true,y_pred,title):                    # [F7] computed once, via ravel
    m=confusion_matrix(y_true,y_pred); tn,fp,fn,tp=m.ravel()
    prec=tp/(tp+fp) if tp+fp else np.nan; rec=tp/(tp+fn) if tp+fn else np.nan
    spec=tn/(tn+fp); f1=2*prec*rec/(prec+rec) if prec+rec else np.nan
    print(f"--- {title} ---")
    print(f"  accuracy {(tp+tn)/m.sum():.4f} | precision {prec:.4f} | recall {rec:.4f}")
    print(f"  specificity {spec:.4f} | F1 {f1:.4f} | balanced acc {(rec+spec)/2:.4f}")
    return m

m1=report(df["recession"].values,(states==crisis_state).astype(int),f"state {crisis_state} only")
ConfusionMatrixDisplay(m1).plot(); plt.title(f"state {crisis_state} vs NBER"); plt.show()
# Out:
# --- state 3 only ---
#   accuracy 0.8546 | precision 0.4444 | recall 0.6452
#   specificity 0.8846 | F1 0.5263 | balanced acc 0.7649

# %% [markdown]
# #### Merging the two recession-carrying states
#
# The Viterbi path splits recessions across two states. Merging them is defensible **if** framed as
# the HMM resolving a recession into distinct phases (onset vs trough) that the NBER binary lumps
# together — it is a claim about NBER's coarseness, not a free parameter to raise recall.

# %%
kap2=kappa_results.iloc[1]["state"].astype(int)
merged=((states==crisis_state)|(states==kap2)).astype(int)
m2=report(df["recession"].values,merged,f"states {crisis_state}+{kap2} merged")
ConfusionMatrixDisplay(m2).plot(); plt.title(f"states {crisis_state}+{kap2} vs NBER"); plt.show()
# Out:
# --- states 3+0 merged ---
#   accuracy 0.8614 | precision 0.4675 | recall 0.7742
#   specificity 0.8738 | F1 0.5830 | balanced acc 0.8240

# %% [markdown]
# ### Lead–lag
#
# **[F4]** The original used `best_model_k`, which after the selection loop held the **K=7** model —
# not `models[chosen_K]`. Because state labels are arbitrary across fits, "state 4" of the K=7 model
# is unrelated to state 4 of the K=6 model. That single bug flattened the correlations to ~0.08–0.14
# and produced the (false) conclusion that the zero lag was the strongest.

# %%
crisis_probability = model.predict_proba(Psi)[:, crisis_state]   # [F4] chosen model
nber = df["recession"].to_numpy()
out=[]
for off in range(-6,7):
    if off>0:   p,n = crisis_probability[:-off], nber[off:]
    elif off<0: p,n = crisis_probability[-off:], nber[:off]
    else:       p,n = crisis_probability, nber
    out.append({"offset":off,"correlation":np.corrcoef(p,n)[0,1]})
lead_lag_df=pd.DataFrame(out)
print(lead_lag_df.round(4).to_string(index=False))
peak=lead_lag_df.loc[lead_lag_df.correlation.idxmax()]
print(f"\npeak correlation {peak.correlation:.4f} at offset {int(peak.offset):+d} months")
# Out:
#  offset  correlation
#      -6       0.6003
#      -5       0.5987
#      -4       0.5871
#      -3       0.5660
#      -2       0.5391
#      -1       0.5090
#       0       0.4573
#       1       0.3967
#       2       0.3330
#       3       0.2697
#       4       0.2166
#       5       0.1634
#       6       0.1186
#
# peak correlation 0.6003 at offset -6 months

# %% [markdown]
# ### Density coherence and non-NBER low-density episodes

# %%
fig,ax=plt.subplots(figsize=(7,4))
data=[rho[states==s] for s in range(chosen_K)]
ax.boxplot(data,labels=[f"S{i}" for i in range(chosen_K)])
ax.set_xlabel("Viterbi state"); ax.set_ylabel(r"$\hat\rho$")
ax.set_title("Embedding density by regime"); ax.grid(alpha=.3)
plt.tight_layout(); plt.show()

recession_mask=df["recession"].values.astype(bool)
potential_threshold=np.median(V[recession_mask])
pad=4
recession_padded=(pd.Series(recession_mask,index=dates)
                  .rolling(2*pad+1,center=True,min_periods=1).max().astype(bool).to_numpy())
series=np.where(~recession_padded,V,-np.inf)
peak_idx,_=find_peaks(series,height=potential_threshold,distance=9,prominence=0.05)
low_density_episodes=pd.DataFrame({"date":dates[peak_idx],"potential":V[peak_idx],
                                   "state":states[peak_idx],"idx":peak_idx}
                                  ).sort_values("potential",ascending=False)
print("non-NBER high-potential episodes:",len(low_density_episodes))
print(low_density_episodes.head(12).to_string(index=False))
# Out:
# non-NBER high-potential episodes: 17
#       date  potential  state  idx
# 2010-05-01   2.765078      3  551
# 2022-09-01   2.569041      4  699
# 1990-01-01   2.206134      2  307
# 1984-08-01   2.190411      5  242
# 1986-02-01   2.117981      2  260
# 2026-03-01   2.011161      2  741
# 1976-01-01   1.893096      2  139
# 2002-05-01   1.844358      3  455
# 1987-01-01   1.791888      2  271
# 1973-02-01   1.782022      5  104
# 2019-05-01   1.768203      2  659
# 2003-04-01   1.741530      3  466

# %% [markdown]
# ## Task IV.3 — rebuilt
#
# **[F6] Why the original figure could not work.** `predict_proba(Psi)` runs forward–backward over
# the **calendar-ordered** 743 months, so $P(S_t=k\mid y_{1:T})$ depends on each month's position in
# time. The original then indexed that calendar posterior by the **graph path's node order**. Graph
# paths are strongly non-chronological — the GFC path visits 2006-03 → 1995-08 → 2006-07 → 1995-10 →
# 1990-07 → 1990-10 → 2001-06 → 2008-10 — so the plotted curve was a scatter of unrelated
# calendar-time posteriors re-ordered by path position, not the posterior of a trajectory. Its
# jaggedness was guaranteed by construction, and no choice of crisis state could fix it.
#
# Separately, the posterior is near-saturated (about 78% of months exceed 0.99; mean entropy 0.08
# against a maximum of $\log 6 \approx 1.79$) because the fitted chain is sticky and K=6
# full-covariance emissions carve the space into well-separated blobs. A smooth monotone rise was
# therefore impossible regardless of indexing.
#
# **What replaces it.** (a) Score each path *as a sequence* under the HMM — the principled question
# "does the model regard this trajectory as plausible?"; (b) plot the Viterbi states each path
# visits, categorically.

# %%
print("chronology of each density-aware path:")
for name,(s,e) in pairs.items():
    p=graph_path(A_dist_sym,BETA,V,s,e)
    print(f"  {name[:34]:34s} {[str(dates[i].date())[:7] for i in p]}")
# Out:
# chronology of each density-aware path:
#   2006 benign -> 2008 GFC            ['2006-03', '2006-12', '1996-04', '2007-03', '2004-08', '2004-03', '2014-01', '2010-08', '2011-08', '2008-10']
#   2019 benign -> 2020 COVID          ['2019-07', '1990-03', '2019-12', '2025-05', '2013-07', '1971-03', '1981-11', '1975-10', '2020-04']
#   2019 benign -> 2021 Fiscal Tighten ['2019-04', '2012-03', '2024-06', '2017-06', '2006-07', '1967-08', '1973-12', '1999-08', '1999-02', '2022-04']
#   1977 benign -> 1982 Recession Trou ['1977-01', '2005-03', '1983-08', '1995-10', '2004-08', '1993-07', '2025-12', '2021-01', '1982-07']

# %%
# (a) [F6] sequence scoring: average log-likelihood per point under the fitted HMM
rows=[]
for name,(s,e) in pairs.items():
    gp   = graph_path(A_dist_sym,BETA,V,s,e)
    gp0  = graph_path(A_dist_sym,0.0,V,s,e)
    lin  = np.linspace(Psi[s],Psi[e],num=len(gp))
    real = Psi[s:e+1]
    rows.append({"event":name,
                 r"graph $\beta=1.5$":model.score(Psi[gp])/len(gp),
                 r"graph $\beta=0$":  model.score(Psi[gp0])/len(gp0),
                 "linear":     model.score(lin)/len(lin),
                 "real path":  model.score(real)/len(real)})
seq=pd.DataFrame(rows).set_index("event")
print("HMM average log-likelihood per point (higher = more plausible sequence)")
print(seq.round(3).to_string())

ax=seq.plot(kind="bar",figsize=(11,4.5))
ax.set_ylabel("avg log-likelihood per point"); ax.grid(axis="y",alpha=.3)
ax.set_title("Do the paths look like plausible trajectories to the HMM?",fontweight="bold")
plt.xticks(rotation=12,ha="right"); plt.tight_layout(); plt.show()
# Out:
# HMM average log-likelihood per point (higher = more plausible sequence)
#                                        graph $\beta=1.5$  graph $\beta=0$  linear  real path
# event
# 2006 benign -> 2008 GFC                            1.960            1.551  -1.820      3.272
# 2019 benign -> 2020 COVID                         -2.760           -4.605  -5.295     -1.975
# 2019 benign -> 2021 Fiscal Tightening              1.180            0.436   1.100      1.901
# 1977 benign -> 1982 Recession Trough               2.741            1.370   1.720      3.720

# %%
# (b) [F6] categorical Viterbi states visited by each path
fig,axes=plt.subplots(2,2,figsize=(13,7)); 
for ax,(name,(s,e)) in zip(axes.ravel(),pairs.items()):
    gp=graph_path(A_dist_sym,BETA,V,s,e)
    lin_idx=[int(np.argmin(np.linalg.norm(Psi-p,axis=1)))
             for p in np.linspace(Psi[s],Psi[e],num=len(gp))]
    real=list(range(s,e+1))
    ax.step(np.linspace(0,1,len(real)),states[real],where="mid",label="real path",lw=2)
    ax.step(np.linspace(0,1,len(gp)),states[gp],where="mid",label=r"graph $\beta=1.5$",lw=2,marker="o",ms=4)
    ax.step(np.linspace(0,1,len(lin_idx)),states[lin_idx],where="mid",label="linear",lw=2,ls="--",marker="x")
    ax.set_yticks(range(chosen_K)); ax.set_ylabel("Viterbi state"); ax.set_xlabel("path progression")
    ax.set_title(name,fontsize=9); ax.grid(alpha=.3); ax.legend(fontsize=7)
plt.suptitle("Regimes visited along each path",fontweight="bold")
plt.tight_layout(); plt.show()

# %% [markdown]
# ### Reading the result
#
# The sequence scores are the headline. The density-aware geodesic is judged substantially more
# plausible than the linear chord on the GFC, COVID and 1982 transitions, with the realised
# trajectory scoring highest of all — the ordering the thesis predicts. Fiscal Tightening is the
# exception and behaves as it has in every phase: a dense-to-dense control where the straight chord
# is already plausible, so the manifold detour buys nothing. Report that consistency rather than
# treating it as a failure.

# %% [markdown]
# # Task IV.4 Sticky HMM sensitivity

# %%
def sticky_transition_prior(K, stickiness):
    prior = np.ones((K, K))
    prior[np.diag_indices(K)] += stickiness
    return prior

def best_sticky_hmm_model(X,K,stickiness,n_starts=RANDOM_STARTS):
    X=np.asarray(X,float); best=-np.inf; bm=None; nf=0
    prior = sticky_transition_prior(K, stickiness)
    for seed in range(n_starts):
        m = hmm.GaussianHMM(n_components=K, covariance_type="full", transmat_prior=prior, n_iter=100, random_state=seed)
        try: m.fit(X); s = m.score(X)
        except Exception: nf+=1; continue
        if np.isfinite(s) and s>best: best=s; bm=m
    if bm is None: raise RuntimeError(f"all inits failed for stickiness={stickiness}")
    return bm,best,nf


stickiness_levels = [0, 5, 20]
sticky_models = {}; sticky_paths = {}

for s in stickiness_levels:
    model, score, nf = best_sticky_hmm_model(Psi, chosen_K, stickiness=s)
    sticky_models[s] = model; sticky_paths[s] = model.predict(Psi)
# Out:
# Model is not converging.  Current: 2839.444675402963 is not greater than 2839.4595923302936. Delta is -0.014916927330432372
# Model is not converging.  Current: 2834.3455019363205 is not greater than 2834.3527030378577. Delta is -0.007201101537248178
# Model is not converging.  Current: 2708.135602622634 is not greater than 2708.1360586715577. Delta is -0.0004560489237519505
# Model is not converging.  Current: 2828.9722769350824 is not greater than 2828.977945038709. Delta is -0.005668103626703669
# Model is not converging.  Current: 2837.740740048989 is not greater than 2837.747855748401. Delta is -0.007115699411770038
# Model is not converging.  Current: 2377.9476377164106 is not greater than 2401.6988899494927. Delta is -23.75125223308214
# Model is not converging.  Current: 2795.0255094611102 is not greater than 2795.0306242269025. Delta is -0.005114765792313847
# Model is not converging.  Current: 2380.6706270422924 is not greater than 2383.4629538080553. Delta is -2.7923267657629367
# Model is not converging.  Current: 2842.9031140945654 is not greater than 2842.904132027343. Delta is -0.0010179327778132574
# Model is not converging.  Current: 2840.188205135768 is not greater than 2840.2003172324426. Delta is -0.012112096674627537
# Model is not converging.  Current: 2835.3695220251066 is not greater than 2835.3763992996296. Delta is -0.006877274523048982
# Model is not converging.  Current: 2835.7358398828965 is not greater than 2835.774977974717. Delta is -0.03913809182040495
# Model is not converging.  Current: 2835.90400616081 is not greater than 2835.9168758515843. Delta is -0.01286969077455069
# Model is not converging.  Current: 2862.2765832992727 is not greater than 2862.2804190308466. Delta is -0.003835731573872181
# Model is not converging.  Current: 2807.0262011685786 is not greater than 2807.032237570113. Delta is -0.006036401534402103
# Model is not converging.  Current: 2697.6220631436813 is not greater than 2697.6239048833954. Delta is -0.0018417397141092806
# Model is not converging.  Current: 2855.1357570465543 is not greater than 2855.1358311297445. Delta is -7.408319015667075e-05
# Model is not converging.  Current: 2833.7408995914057 is not greater than 2833.741350633723. Delta is -0.00045104231730874744
# Model is not converging.  Current: 2889.313552084442 is not greater than 2889.3144037311654. Delta is -0.0008516467232766445
# Model is not converging.  Current: 2822.6747353026662 is not greater than 2822.6766504412644. Delta is -0.0019151385981786007
# Model is not converging.  Current: 2876.6071830238684 is not greater than 2876.6124160576933. Delta is -0.005233033824879385
# Model is not converging.  Current: 2835.6799482185006 is not greater than 2835.707381565123. Delta is -0.027433346622274257
# Model is not converging.  Current: 2876.510686413366 is not greater than 2876.5211236387872. Delta is -0.010437225421355834
# Model is not converging.  Current: 2875.878673571811 is not greater than 2875.8872309470753. Delta is -0.008557375264445
# Model is not converging.  Current: 2384.122764834368 is not greater than 2388.6938465074504. Delta is -4.571081673082517
# Model is not converging.  Current: 2849.6856083826333 is not greater than 2849.686258881058. Delta is -0.0006504984248749679
# Model is not converging.  Current: 2827.2981592904403 is not greater than 2827.3044444458897. Delta is -0.006285155449404556
# Model is not converging.  Current: 2828.1505325008143 is not greater than 2828.1934828122044. Delta is -0.042950311390086426
# Model is not converging.  Current: 2829.8397051927805 is not greater than 2829.9258818168746. Delta is -0.08617662409415061
# Model is not converging.  Current: 2873.7224690616204 is not greater than 2873.722668274502. Delta is -0.00019921288185287267
# Model is not converging.  Current: 2885.451159779484 is not greater than 2885.4980950274885. Delta is -0.04693524800450177
# Model is not converging.  Current: 2862.548880738261 is not greater than 2862.552520692092. Delta is -0.0036399538312252844
# Model is not converging.  Current: 2698.854903865962 is not greater than 2698.8613548215285. Delta is -0.00645095556637898
# Model is not converging.  Current: 2868.7439689667535 is not greater than 2868.75595610734. Delta is -0.011987140586370515
# Model is not converging.  Current: 2690.9771419028507 is not greater than 2690.98431381109. Delta is -0.0071719082393428835
# Model is not converging.  Current: 2663.732829488251 is not greater than 2663.884757206661. Delta is -0.15192771841020658
# Model is not converging.  Current: 2833.1159298772795 is not greater than 2833.1219176854074. Delta is -0.005987808127883909
# Model is not converging.  Current: 2829.400364253145 is not greater than 2829.454770356381. Delta is -0.054406103235578485
# Model is not converging.  Current: 2829.5768824793877 is not greater than 2829.5771846172497. Delta is -0.00030213786203603377
# Model is not converging.  Current: 2860.2245709551685 is not greater than 2860.2248254459364. Delta is -0.00025449076792938286
# Model is not converging.  Current: 2718.406973885868 is not greater than 2718.4128310967426. Delta is -0.005857210874637531
# Model is not converging.  Current: 2390.3757797893945 is not greater than 2401.7753053903953. Delta is -11.399525601000732
# Model is not converging.  Current: 2830.5383185424357 is not greater than 2830.595799357109. Delta is -0.057480814673454006
# Model is not converging.  Current: 2830.2090761378736 is not greater than 2830.2376039788574. Delta is -0.028527840983770147
# Model is not converging.  Current: 2827.6091553574183 is not greater than 2827.6140857093446. Delta is -0.004930351926304866
# Model is not converging.  Current: 2829.590180753845 is not greater than 2829.5965977261794. Delta is -0.006416972334591264
# Model is not converging.  Current: 2702.0484849004215 is not greater than 2702.1577122025683. Delta is -0.10922730214679177
# Model is not converging.  Current: 2803.03599574289 is not greater than 2803.082759227779. Delta is -0.04676348488919757
# Model is not converging.  Current: 2808.7002934906177 is not greater than 2826.864877605641. Delta is -18.164584115023445

# %%
baseline_model = sticky_models[0]
baseline_path = sticky_paths[0]

aligned_paths = {0: baseline_path}

for s in stickiness_levels[1:]:
    model = sticky_models[s]

    cost = cdist(model.means_, baseline_model.means_)
    sticky_labels, baseline_labels = linear_sum_assignment(cost)

    mapping = dict(zip(sticky_labels, baseline_labels))

    aligned_paths[s] = np.array([
        mapping[state] for state in sticky_paths[s]
    ])

# %%
results = []

for s in stickiness_levels:
    path = aligned_paths[s]
    model = sticky_models[s]

    results.append({
        "stickiness": s,
        "agreement_with_baseline": np.mean(path == baseline_path),
        "number_of_switches": np.sum(path[1:] != path[:-1]),
        "mean_self_transition": np.diag(model.transmat_).mean()
    })

sticky_results = pd.DataFrame(results)
sticky_results
# Out:
#    stickiness  agreement_with_baseline  number_of_switches  \
# 0           0                 1.000000                  68
# 1           5                 0.855989                  63
# 2          20                 0.855989                  63
#
#    mean_self_transition
# 0              0.893462
# 1              0.913652
# 2              0.927294
